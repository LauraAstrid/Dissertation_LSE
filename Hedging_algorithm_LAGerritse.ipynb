# %% [markdown]
# We import all the libraries that we will need in the algorithm, most importantly the two neural network libraries that Python offers: Tensorflow and Keras.
# It is important to note that this Jupyter Notebook is adapted from the Jupyter Notebook posted by Josef Teichmann (one of the authors of the paper in which the deep hedging framework was proposed, https://doi.org/10.1080/14697688.2019.1571683) for his course at ETH Zürich. His notebooks can be found on this website: https://people.math.ethz.ch/~jteichma/index.php?content=teach_mlf2019

# %%
import numpy as np
import tensorflow as tf
import math
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Concatenate, Dropout, Subtract, \
                        Flatten, MaxPooling2D, Multiply, Lambda, Add, Dot
from keras.backend import constant
from keras import optimizers

from keras.engine.topology import Layer
from keras.models import Model
from keras.layers import Input
from keras import initializers
from keras.constraints import max_norm
import keras.backend as K

import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
# Out:
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# Next, we show how we can model random stock price trajectories within the Black Scholes model, by using the property that B-S stock prices have lognormal increments.
# Additionally, all important parameters are initialised.

# %%
# Trajectories of the Black scholes model
# Let it run to initialize the following parameters, the trajectories 
# are not needed afterwards

N=20 # time disrectization
S0=1 # initial value of the asset
strike=1 # strike for the call option 
T=1.0 # maturity
sigma=0.2 # volatility in Black Scholes
R=10 # number of Trajectories

logS= np.zeros((N,R))
logS[0,]=np.log(S0)*np.ones((1,R))

for i in range(R):
    for j in range(N-1):
        increment = np.random.normal(-(sigma)**2*T/(2*N),sigma*np.sqrt(T)/np.sqrt(N))
        logS[j+1,i] =logS[j,i]+increment

S=np.exp(logS)
#added to compare it with the X dynamics in the portfolio maximization model
print(np.mean(S[N-1,:]))
print(np.std(S[N-1,:]))

for i in range(R):
   plt.plot(S[:,i])
plt.show()
# Out:
# 0.9843241473630251
# 0.22561420238359464

# %% [markdown]
# We define the black scholes price of a European call option at the initial time t=0.

# %%
import scipy.stats as scipy
from scipy.stats import norm

#Blackscholes price

def BS(S0, strike, T, sigma):
    return S0*scipy.norm.cdf((np.log(S0/strike)+0.5*T*sigma**2)/(np.sqrt(T)*sigma))-strike*scipy.norm.cdf((np.log(S0/strike)-0.5*T*sigma**2)/(np.sqrt(T)*sigma))

priceBS=BS(S0,strike,T,sigma)
print('Price of a Call option in the Black scholes model with initial price', 
      S0, 'strike', strike, 'maturity', T , 'and volatility' , sigma, 'is equal to', BS(S0,strike,T,sigma))
# Out:
# Price of a Call option in the Black scholes model with initial price 1 strike 1 maturity 1.0 and volatility 0.2 is equal to 0.07965567455405798

# %% [markdown]
# Here we define the structure of the neural networks, choosing the number of layers and the number of neurons. The parameter d also includes the final output layer, so when d=3 there are actually 2 hidden layers in the strategy.
# The hidden layers have the hypertolic tangent function as their activation function,
# the weights and bias are randomly determined and the final layer uses a linear function to calculate the output.

# %%
#Definition of neural networks for hedging strategies

m = 1 # dimension of price
d = 3 # number of layers in strategy
n = 8  # nodes in the first but last layers

# architecture is the same for all networks
layers = []
for j in range(N):
    for i in range(d):
        if i < d-1:
            nodes = n
            layer = Dense(nodes, activation='tanh',trainable=True,
                      kernel_initializer=initializers.RandomNormal(0,1),#kernel_initializer='random_normal',
                      bias_initializer='random_normal',
                      name=str(i)+str(j))
        else:
            nodes = m
            layer = Dense(nodes, activation='linear', trainable=True,
                          kernel_initializer=initializers.RandomNormal(0,0.1),#kernel_initializer='random_normal',
                          bias_initializer='random_normal',
                          name=str(i)+str(j))
        layers = layers + [layer]

# %% [markdown]
# We plot the activation function, tanh(x), so that we can see how it functions as a step function.

# %%
import matplotlib.pyplot as plt
h=np.linspace(-10,10,2000)
v= np.tanh(h)
plt.plot(h,v,'b')
plt.show()

# %% [markdown]
# We build the algorithm, with a neural network for each time interval. The price is updated at each interval and functions as the input in the next neural network. The algoritmic implementation has five input vectors with the initial price, the initial hedge, the hedge evaluation initialisation, the Black-Scholes price of the option and the log price increments.
#
# The output of the model consists of 22 vectors (for N=20), the first vector is the loss, the next 20 are all the optimal hedigng strategies for each time interval and the final vector is the BS price of the option.

# %%
#Implementing the loss function
# Inputs is the training set below, containing the price S0, 
#the initial hedging being 0, and the increments of the log price process 
price = Input(shape=(m,))
hedge = Input(shape=(m,))
hedgeeval = Input(shape=(m,))
premium = Input(shape=(m,))

inputs = [price]+[hedge]+[hedgeeval]+[premium]
outputhelper=[]

premium = Dense(m, activation='linear', trainable=True,
                kernel_initializer=initializers.RandomNormal(0,1),
                bias_initializer=initializers.RandomNormal(0,1))(premium)

for j in range(N):
    strategy = price
    strategyeval=hedgeeval
    for k in range(d):
        strategy= layers[k+(j)*d](strategy) # strategy at j is the hedging strategy at j , i.e. the neural network g_j
        strategyeval=layers[k+(j)*d](strategyeval)
    incr = Input(shape=(m,))
    logprice= Lambda(lambda x : K.log(x))(price)
    logprice = Add()([logprice, incr])
    pricenew=Lambda(lambda x : K.exp(x))(logprice)# creating the price at time j+1
    priceincr=Subtract()([pricenew, price])
    hedgenew = Multiply()([strategy, priceincr])
    hedge = Add()([hedge,hedgenew]) # building up the discretized stochastic integral
    inputs = inputs + [incr]
    outputhelper = outputhelper + [strategyeval]
    price=pricenew
payoff= Lambda(lambda x : 0.5*(K.abs(x-strike)+x-strike))(price) 
outputs = Subtract()([payoff,hedge]) 
outputs = Subtract()([outputs,premium]) # payoff minus price minus hedge 
outputs= [outputs] + outputhelper +[premium]
print(len(outputs))
outputs = Concatenate()(outputs)

model_hedge_strat = Model(inputs=inputs, outputs=outputs)
# Out:
# 22

# %% [markdown]
# Using the summary function, we can see the number of parameters in the neural network implementation, i.e. the total number of weights and biases for each neuron.

# %%
model_hedge_strat.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1)            0           input_1[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1)            0           lambda_1[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1)            0           add_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1)            0           lambda_2[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1)            0           lambda_3[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1)            0           add_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1)            0           lambda_4[0][0]
# __________________________________________________________________________________________________
# input_7 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1)            0           lambda_5[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1)            0           add_5[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1)            0           lambda_6[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 1)            0           lambda_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1)            0           add_7[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1)            0           lambda_8[0][0]
# __________________________________________________________________________________________________
# input_9 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 1)            0           lambda_9[0][0]
#                                                                  input_9[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1)            0           add_9[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 1)            0           lambda_10[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 1)            0           lambda_11[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 1)            0           add_11[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 1)            0           lambda_12[0][0]
# __________________________________________________________________________________________________
# input_11 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 1)            0           lambda_13[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 1)            0           add_13[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 1)            0           lambda_14[0][0]
# __________________________________________________________________________________________________
# input_12 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 1)            0           lambda_15[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 1)            0           add_15[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 1)            0           lambda_16[0][0]
# __________________________________________________________________________________________________
# input_13 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 1)            0           lambda_17[0][0]
#                                                                  input_13[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 1)            0           add_17[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 1)            0           lambda_18[0][0]
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 1)            0           lambda_19[0][0]
#                                                                  input_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 1)            0           add_19[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 1)            0           lambda_20[0][0]
# __________________________________________________________________________________________________
# input_15 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 1)            0           lambda_21[0][0]
#                                                                  input_15[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           add_21[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 1)            0           lambda_22[0][0]
# __________________________________________________________________________________________________
# input_16 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 1)            0           lambda_23[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 1)            0           add_23[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 1)            0           lambda_24[0][0]
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 1)            0           lambda_25[0][0]
#                                                                  input_17[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 1)            0           add_25[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 1)            0           lambda_26[0][0]
# __________________________________________________________________________________________________
# input_18 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# 00 (Dense)                      (None, 8)            16          input_1[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 1)            0           lambda_27[0][0]
#                                                                  input_18[0][0]
# __________________________________________________________________________________________________
# 10 (Dense)                      (None, 8)            72          00[0][0]
#                                                                  00[1][0]
# __________________________________________________________________________________________________
# 01 (Dense)                      (None, 8)            16          lambda_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 1)            0           add_27[0][0]
# __________________________________________________________________________________________________
# 20 (Dense)                      (None, 1)            9           10[0][0]
#                                                                  10[1][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 1)            0           lambda_2[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# 11 (Dense)                      (None, 8)            72          01[0][0]
#                                                                  01[1][0]
# __________________________________________________________________________________________________
# 02 (Dense)                      (None, 8)            16          lambda_4[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 1)            0           lambda_28[0][0]
# __________________________________________________________________________________________________
# input_19 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1)            0           20[0][0]
#                                                                  subtract_1[0][0]
# __________________________________________________________________________________________________
# 21 (Dense)                      (None, 1)            9           11[0][0]
#                                                                  11[1][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 1)            0           lambda_4[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# 12 (Dense)                      (None, 8)            72          02[0][0]
#                                                                  02[1][0]
# __________________________________________________________________________________________________
# 03 (Dense)                      (None, 8)            16          lambda_6[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 1)            0           lambda_29[0][0]
#                                                                  input_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1)            0           input_2[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1)            0           21[0][0]
#                                                                  subtract_2[0][0]
# __________________________________________________________________________________________________
# 22 (Dense)                      (None, 1)            9           12[0][0]
#                                                                  12[1][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 1)            0           lambda_6[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# 13 (Dense)                      (None, 8)            72          03[0][0]
#                                                                  03[1][0]
# __________________________________________________________________________________________________
# 04 (Dense)                      (None, 8)            16          lambda_8[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 1)            0           add_29[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 1)            0           add_2[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 1)            0           22[0][0]
#                                                                  subtract_3[0][0]
# __________________________________________________________________________________________________
# 23 (Dense)                      (None, 1)            9           13[0][0]
#                                                                  13[1][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 1)            0           lambda_8[0][0]
#                                                                  lambda_6[0][0]
# __________________________________________________________________________________________________
# 14 (Dense)                      (None, 8)            72          04[0][0]
#                                                                  04[1][0]
# __________________________________________________________________________________________________
# 05 (Dense)                      (None, 8)            16          lambda_10[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 1)            0           lambda_30[0][0]
# __________________________________________________________________________________________________
# input_20 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 1)            0           add_4[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1)            0           23[0][0]
#                                                                  subtract_4[0][0]
# __________________________________________________________________________________________________
# 24 (Dense)                      (None, 1)            9           14[0][0]
#                                                                  14[1][0]
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 1)            0           lambda_10[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# 15 (Dense)                      (None, 8)            72          05[0][0]
#                                                                  05[1][0]
# __________________________________________________________________________________________________
# 06 (Dense)                      (None, 8)            16          lambda_12[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 1)            0           lambda_31[0][0]
#                                                                  input_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1)            0           add_6[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1)            0           24[0][0]
#                                                                  subtract_5[0][0]
# __________________________________________________________________________________________________
# 25 (Dense)                      (None, 1)            9           15[0][0]
#                                                                  15[1][0]
# __________________________________________________________________________________________________
# subtract_6 (Subtract)           (None, 1)            0           lambda_12[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# 16 (Dense)                      (None, 8)            72          06[0][0]
#                                                                  06[1][0]
# __________________________________________________________________________________________________
# 07 (Dense)                      (None, 8)            16          lambda_14[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 1)            0           add_31[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 1)            0           add_8[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1)            0           25[0][0]
#                                                                  subtract_6[0][0]
# __________________________________________________________________________________________________
# 26 (Dense)                      (None, 1)            9           16[0][0]
#                                                                  16[1][0]
# __________________________________________________________________________________________________
# subtract_7 (Subtract)           (None, 1)            0           lambda_14[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# 17 (Dense)                      (None, 8)            72          07[0][0]
#                                                                  07[1][0]
# __________________________________________________________________________________________________
# 08 (Dense)                      (None, 8)            16          lambda_16[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 1)            0           lambda_32[0][0]
# __________________________________________________________________________________________________
# input_21 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 1)            0           add_10[0][0]
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1)            0           26[0][0]
#                                                                  subtract_7[0][0]
# __________________________________________________________________________________________________
# 27 (Dense)                      (None, 1)            9           17[0][0]
#                                                                  17[1][0]
# __________________________________________________________________________________________________
# subtract_8 (Subtract)           (None, 1)            0           lambda_16[0][0]
#                                                                  lambda_14[0][0]
# __________________________________________________________________________________________________
# 18 (Dense)                      (None, 8)            72          08[0][0]
#                                                                  08[1][0]
# __________________________________________________________________________________________________
# 09 (Dense)                      (None, 8)            16          lambda_18[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 1)            0           lambda_33[0][0]
#                                                                  input_21[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 1)            0           add_12[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 1)            0           27[0][0]
#                                                                  subtract_8[0][0]
# __________________________________________________________________________________________________
# 28 (Dense)                      (None, 1)            9           18[0][0]
#                                                                  18[1][0]
# __________________________________________________________________________________________________
# subtract_9 (Subtract)           (None, 1)            0           lambda_18[0][0]
#                                                                  lambda_16[0][0]
# __________________________________________________________________________________________________
# 19 (Dense)                      (None, 8)            72          09[0][0]
#                                                                  09[1][0]
# __________________________________________________________________________________________________
# 010 (Dense)                     (None, 8)            16          lambda_20[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 1)            0           add_33[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 1)            0           add_14[0][0]
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 1)            0           28[0][0]
#                                                                  subtract_9[0][0]
# __________________________________________________________________________________________________
# 29 (Dense)                      (None, 1)            9           19[0][0]
#                                                                  19[1][0]
# __________________________________________________________________________________________________
# subtract_10 (Subtract)          (None, 1)            0           lambda_20[0][0]
#                                                                  lambda_18[0][0]
# __________________________________________________________________________________________________
# 110 (Dense)                     (None, 8)            72          010[0][0]
#                                                                  010[1][0]
# __________________________________________________________________________________________________
# 011 (Dense)                     (None, 8)            16          lambda_22[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 1)            0           lambda_34[0][0]
# __________________________________________________________________________________________________
# input_22 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 1)            0           add_16[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 1)            0           29[0][0]
#                                                                  subtract_10[0][0]
# __________________________________________________________________________________________________
# 210 (Dense)                     (None, 1)            9           110[0][0]
#                                                                  110[1][0]
# __________________________________________________________________________________________________
# subtract_11 (Subtract)          (None, 1)            0           lambda_22[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# 111 (Dense)                     (None, 8)            72          011[0][0]
#                                                                  011[1][0]
# __________________________________________________________________________________________________
# 012 (Dense)                     (None, 8)            16          lambda_24[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 1)            0           lambda_35[0][0]
#                                                                  input_22[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 1)            0           add_18[0][0]
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 1)            0           210[0][0]
#                                                                  subtract_11[0][0]
# __________________________________________________________________________________________________
# 211 (Dense)                     (None, 1)            9           111[0][0]
#                                                                  111[1][0]
# __________________________________________________________________________________________________
# subtract_12 (Subtract)          (None, 1)            0           lambda_24[0][0]
#                                                                  lambda_22[0][0]
# __________________________________________________________________________________________________
# 112 (Dense)                     (None, 8)            72          012[0][0]
#                                                                  012[1][0]
# __________________________________________________________________________________________________
# 013 (Dense)                     (None, 8)            16          lambda_26[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 1)            0           add_35[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 1)            0           add_20[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 1)            0           211[0][0]
#                                                                  subtract_12[0][0]
# __________________________________________________________________________________________________
# 212 (Dense)                     (None, 1)            9           112[0][0]
#                                                                  112[1][0]
# __________________________________________________________________________________________________
# subtract_13 (Subtract)          (None, 1)            0           lambda_26[0][0]
#                                                                  lambda_24[0][0]
# __________________________________________________________________________________________________
# 113 (Dense)                     (None, 8)            72          013[0][0]
#                                                                  013[1][0]
# __________________________________________________________________________________________________
# 014 (Dense)                     (None, 8)            16          lambda_28[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 1)            0           lambda_36[0][0]
# __________________________________________________________________________________________________
# input_23 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 1)            0           add_22[0][0]
#                                                                  multiply_12[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 1)            0           212[0][0]
#                                                                  subtract_13[0][0]
# __________________________________________________________________________________________________
# 213 (Dense)                     (None, 1)            9           113[0][0]
#                                                                  113[1][0]
# __________________________________________________________________________________________________
# subtract_14 (Subtract)          (None, 1)            0           lambda_28[0][0]
#                                                                  lambda_26[0][0]
# __________________________________________________________________________________________________
# 114 (Dense)                     (None, 8)            72          014[0][0]
#                                                                  014[1][0]
# __________________________________________________________________________________________________
# 015 (Dense)                     (None, 8)            16          lambda_30[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 1)            0           lambda_37[0][0]
#                                                                  input_23[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 1)            0           add_24[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 1)            0           213[0][0]
#                                                                  subtract_14[0][0]
# __________________________________________________________________________________________________
# 214 (Dense)                     (None, 1)            9           114[0][0]
#                                                                  114[1][0]
# __________________________________________________________________________________________________
# subtract_15 (Subtract)          (None, 1)            0           lambda_30[0][0]
#                                                                  lambda_28[0][0]
# __________________________________________________________________________________________________
# 115 (Dense)                     (None, 8)            72          015[0][0]
#                                                                  015[1][0]
# __________________________________________________________________________________________________
# 016 (Dense)                     (None, 8)            16          lambda_32[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 1)            0           add_37[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 1)            0           add_26[0][0]
#                                                                  multiply_14[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 1)            0           214[0][0]
#                                                                  subtract_15[0][0]
# __________________________________________________________________________________________________
# 215 (Dense)                     (None, 1)            9           115[0][0]
#                                                                  115[1][0]
# __________________________________________________________________________________________________
# subtract_16 (Subtract)          (None, 1)            0           lambda_32[0][0]
#                                                                  lambda_30[0][0]
# __________________________________________________________________________________________________
# 116 (Dense)                     (None, 8)            72          016[0][0]
#                                                                  016[1][0]
# __________________________________________________________________________________________________
# 017 (Dense)                     (None, 8)            16          lambda_34[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 1)            0           lambda_38[0][0]
# __________________________________________________________________________________________________
# input_24 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 1)            0           add_28[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 1)            0           215[0][0]
#                                                                  subtract_16[0][0]
# __________________________________________________________________________________________________
# 216 (Dense)                     (None, 1)            9           116[0][0]
#                                                                  116[1][0]
# __________________________________________________________________________________________________
# subtract_17 (Subtract)          (None, 1)            0           lambda_34[0][0]
#                                                                  lambda_32[0][0]
# __________________________________________________________________________________________________
# 117 (Dense)                     (None, 8)            72          017[0][0]
#                                                                  017[1][0]
# __________________________________________________________________________________________________
# 018 (Dense)                     (None, 8)            16          lambda_36[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 1)            0           lambda_39[0][0]
#                                                                  input_24[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 1)            0           add_30[0][0]
#                                                                  multiply_16[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 1)            0           216[0][0]
#                                                                  subtract_17[0][0]
# __________________________________________________________________________________________________
# 217 (Dense)                     (None, 1)            9           117[0][0]
#                                                                  117[1][0]
# __________________________________________________________________________________________________
# subtract_18 (Subtract)          (None, 1)            0           lambda_36[0][0]
#                                                                  lambda_34[0][0]
# __________________________________________________________________________________________________
# 118 (Dense)                     (None, 8)            72          018[0][0]
#                                                                  018[1][0]
# __________________________________________________________________________________________________
# 019 (Dense)                     (None, 8)            16          lambda_38[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 1)            0           add_39[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 1)            0           add_32[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 1)            0           217[0][0]
#                                                                  subtract_18[0][0]
# __________________________________________________________________________________________________
# 218 (Dense)                     (None, 1)            9           118[0][0]
#                                                                  118[1][0]
# __________________________________________________________________________________________________
# subtract_19 (Subtract)          (None, 1)            0           lambda_38[0][0]
#                                                                  lambda_36[0][0]
# __________________________________________________________________________________________________
# 119 (Dense)                     (None, 8)            72          019[0][0]
#                                                                  019[1][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 1)            0           add_34[0][0]
#                                                                  multiply_18[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 1)            0           218[0][0]
#                                                                  subtract_19[0][0]
# __________________________________________________________________________________________________
# 219 (Dense)                     (None, 1)            9           119[0][0]
#                                                                  119[1][0]
# __________________________________________________________________________________________________
# subtract_20 (Subtract)          (None, 1)            0           lambda_40[0][0]
#                                                                  lambda_38[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 1)            0           add_36[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 1)            0           219[0][0]
#                                                                  subtract_20[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 1)            0           lambda_40[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 1)            0           add_38[0][0]
#                                                                  multiply_20[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# subtract_21 (Subtract)          (None, 1)            0           lambda_41[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2           input_4[0][0]
# __________________________________________________________________________________________________
# subtract_22 (Subtract)          (None, 1)            0           subtract_21[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 22)           0           subtract_22[0][0]
#                                                                  20[1][0]
#                                                                  21[1][0]
#                                                                  22[1][0]
#                                                                  23[1][0]
#                                                                  24[1][0]
#                                                                  25[1][0]
#                                                                  26[1][0]
#                                                                  27[1][0]
#                                                                  28[1][0]
#                                                                  29[1][0]
#                                                                  210[1][0]
#                                                                  211[1][0]
#                                                                  212[1][0]
#                                                                  213[1][0]
#                                                                  214[1][0]
#                                                                  215[1][0]
#                                                                  216[1][0]
#                                                                  217[1][0]
#                                                                  218[1][0]
#                                                                  219[1][0]
#                                                                  dense_1[0][0]
# ==================================================================================================
# Total params: 1,942
# Trainable params: 1,942
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# We define the training data with 100.000 training points, and all the input vectors as defined in the model structure.
# ytrain is an array with 21 columns, all zeroes, because we are aiming for a hedge that is as low as possible.

# %%
Ktrain = 10**5
initialprice = S0

# xtrain consists of the price S0, 
#the initial hedging being 0, and the increments of the log price process 
xtrain = ([initialprice*np.ones((Ktrain,m))] +
          [np.zeros((Ktrain,m))]+
          [np.ones((Ktrain,m))] +
          [priceBS*np.ones((Ktrain,m))]+
          [np.random.normal(-(sigma)**2*T/(2*N),sigma*np.sqrt(T)/np.sqrt(N),(Ktrain,m)) for i in range(N)])
print(len(xtrain))

ytrain=np.zeros((Ktrain,1+N))
# Out:
# 24

# %% [markdown]
# This is the custom loss function, which is the mean squared difference between the true y and the predicted y.

# %%
#import keras
from keras import losses
def custom_loss(y_true,y_pred):
    #return losses.mean_squared_error(y_true[0], y_pred[0])
    z = y_pred[:,0]-y_true[:,0]
    z=K.mean(K.square(z))
    return z

# %% [markdown]
# This is the compilation of the model, where we choose the optimizer Adam which is a more complicated version of the stochastic gradient descent algorithm with an adaptive learning rate. Using the first two lines, it is possible to change the learning rate from the default rate 0.001.

# %%
#from keras import optimizers
#adam=optimizers.Adam(lr=0.0005)

model_hedge_strat.compile(optimizer='adam',loss=custom_loss)

# %% [markdown]
# Now, we fit the model on the training data for 5 iterations and 1 epoch.

# %%
import matplotlib.pyplot as plt

for i in range(5):
    model_hedge_strat.fit(x=xtrain,y=ytrain, epochs=1,verbose=True)
# Out:
# WARNING:tensorflow:From C:\Users\laura\anaconda3\envs\Dissertation\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1
# 100000/100000 [==============================] - 18s 182us/step - loss: 0.0053
# Epoch 1/1
# 100000/100000 [==============================] - 18s 176us/step - loss: 4.3614e-04
# Epoch 1/1
# 100000/100000 [==============================] - 18s 184us/step - loss: 3.3516e-04
# Epoch 1/1
# 100000/100000 [==============================] - 19s 187us/step - loss: 2.9036e-04
# Epoch 1/1
# 100000/100000 [==============================] - 19s 191us/step - loss: 2.7174e-04

# %% [markdown]
# We print the mean and sd of the loss, then we print the mean and standard deviation of the B-S price of the option. The price of the option outputted by the algorithm is very close to when we calculate it directly (and not run it through the neural network as an extra input). We set the number of bins to be 1000 to see the right distribution.
#
# The test data is made in the exact same way as the training data.

# %%
Ktest1 = 50000
xtest1 = ([initialprice*np.ones((Ktest1,m))] +
          [np.zeros((Ktest1,m))]+
          [np.ones((Ktest1,m))] +
          [priceBS*np.ones((Ktest1,m))]+
          [np.random.normal(-(sigma)**2*T/(2*N),sigma*np.sqrt(T)/np.sqrt(N),(Ktest1,m)) for i in range(N)])
y_test1 = model_hedge_strat.predict(xtest1)
plt.hist(y_test1[:,0], bins=1000)
plt.show()
print('mean of loss is', np.mean(y_test1[:,0]))
print('standard deviation of loss is', np.std(y_test1[:,0]))
print('mean of BS-price is', np.mean(y_test1[:, N+1]))
print('standard deviation of BS-price is', np.std(y_test1[:, N+1]))
# Out:
# mean of loss is 0.0009821227
# standard deviation of loss is 0.016544541
# mean of BS-price is 0.07870578
# standard deviation of BS-price is 7.450581e-09

# %% [markdown]
# Here, we print out the list of hedges for each time interval up to N and plot a graph of the hedges with the time intervals on the x axis.

# %%
hedge_list = []
for i in range(N):
    hedge_list.append(np.mean(y_test1[:,1+i]))
print(hedge_list)
#now plot the hedges per time interval in a graph
time = np.linspace(1,N, N)
plt.plot(time,hedge_list)
# Out:
# [0.55575746, 0.580247, 0.5674205, 0.58509916, 0.52791697, 0.52751124, 0.52843136, 0.5215712, 0.5304466, 0.53853935, 0.5728584, 0.519547, 0.53280115, 0.54134417, 0.52052915, 0.49975875, 0.4921227, 0.55689186, 0.5919338, 0.39024785]

# %% [markdown]
# Here we create a smaller testing data set, in order to plot the hedging strategies for an observed range of stock prices from 0.5 to 1.5. We choose one time interval out of the 20. We compare the neural hedging strategy (the blue line) to the Black-Scholes delta hedge for the European call option, which is the purple line.

# %%
Ktest= 10
xtest = ([initialprice*np.ones((Ktest,m))] +
          [np.zeros((Ktest,m))]+
          [np.linspace(0.5,1.5,Ktest)] +#change this if you go to higher dimensions
          [priceBS*np.ones((Ktest,m))]+
          [np.random.normal(-(sigma)**2*T/(2*N),sigma*np.sqrt(T)/np.sqrt(N),(Ktest,m)) for i in range(N)])
y_whole = model_hedge_strat.predict(xtest)
y = y_whole[:,10]
print(y)
# Out:
# [-0.16260266 -0.11951806 -0.03446465  0.13000283  0.3913467   0.6757605
#   0.87982273  0.9891632   1.0391165   1.0591527 ]

# %%
l = 9
s=np.linspace(0.5,1.5,Ktest)
z=scipy.norm.cdf((np.log(s/strike)+0.5*(T-l*T/N)*sigma**2)/(np.sqrt(T-l*T/N)*sigma))
plt.plot(s,y,'b',s,z,'m')
plt.show()
